# %% [markdown]
# # Урок 1. Алгоритм линейной регрессии. Градиентный спуск.

# %% [markdown]
# 1. Подберите скорость обучения (eta) и количество итераций

# %%
import numpy as np
#Данные взяты из методички к лекции
X = np.array([[ 1,  1],
              [ 1,  1],
              [ 1,  2],
              [ 1,  5],
              [ 1,  3],
              [ 1,  0],
              [ 1,  5],
              [ 1, 10],
              [ 1,  1],
              [ 1,  2]])

def calc_mse(y, y_pred):
    err = np.mean((y - y_pred)**2)
    return err

y = [45, 55, 50, 55, 60, 35, 75, 80, 50, 60]

# %%
n = X.shape[0]

eta = 1e-2 
n_iter = 100

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    for k in range(W.shape[0]):
        W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    if i % 10 == 0:
        eta /= 1.1
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
# Out:
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [2.08 4.27], MSE = 3047.75
# Iteration #10: W_new = [ 6.67106886 10.61676385], MSE = 749.71
# Iteration #20: W_new = [ 9.49320908 10.25731657], MSE = 648.91
# Iteration #30: W_new = [11.85740092  9.83349244], MSE = 570.46
# Iteration #40: W_new = [13.86876921  9.46898661], MSE = 508.03
# Iteration #50: W_new = [15.59085668  9.15672679], MSE = 457.73
# Iteration #60: W_new = [17.07337653  8.88789585], MSE = 416.77
# Iteration #70: W_new = [18.35601294  8.65530964], MSE = 383.06
# Iteration #80: W_new = [19.47073522  8.45317196], MSE = 355.08
# Iteration #90: W_new = [20.44350656  8.27677488], MSE = 331.65

# %%
n = X.shape[1]

eta = 1e-2 
n_iter = 201

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    for k in range(W.shape[0]):
        W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    if i % 10 == 0:
        eta /= 1.1
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
# Out:
# Number of objects = 2
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [ 6.4  19.35], MSE = 3047.75
# Iteration #10: W_new = [18.77319138  8.6270072 ], MSE = 398.58
# Iteration #20: W_new = [27.15289315  7.06014716], MSE = 207.1
# Iteration #30: W_new = [32.4241672   6.10426679], MSE = 124.63
# Iteration #40: W_new = [35.85213314  5.48265802], MSE = 86.53
# Iteration #50: W_new = [38.15155609  5.06569312], MSE = 67.79
# Iteration #60: W_new = [39.73790007  4.7780341 ], MSE = 58.04
# Iteration #70: W_new = [40.86051023  4.57446606], MSE = 52.69
# Iteration #80: W_new = [41.67349173  4.4270444 ], MSE = 49.62
# Iteration #90: W_new = [42.2746909  4.3180262], MSE = 47.78
# Iteration #100: W_new = [42.727794    4.23586294], MSE = 46.63
# Iteration #110: W_new = [43.07521157  4.17286412], MSE = 45.89
# Iteration #120: W_new = [43.34578807  4.12379924], MSE = 45.4
# Iteration #130: W_new = [43.55952748  4.08504089], MSE = 45.06
# ...

# %%
n = X.shape[1]

eta = 1e-2 
n_iter = 1001

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    for k in range(W.shape[0]):
        W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    if i % 10 == 0:
        eta /= 1.1
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
# Out:
# Number of objects = 2
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [ 6.4  19.35], MSE = 3047.75
# Iteration #10: W_new = [18.77319138  8.6270072 ], MSE = 398.58
# Iteration #20: W_new = [27.15289315  7.06014716], MSE = 207.1
# Iteration #30: W_new = [32.4241672   6.10426679], MSE = 124.63
# Iteration #40: W_new = [35.85213314  5.48265802], MSE = 86.53
# Iteration #50: W_new = [38.15155609  5.06569312], MSE = 67.79
# Iteration #60: W_new = [39.73790007  4.7780341 ], MSE = 58.04
# Iteration #70: W_new = [40.86051023  4.57446606], MSE = 52.69
# Iteration #80: W_new = [41.67349173  4.4270444 ], MSE = 49.62
# Iteration #90: W_new = [42.2746909  4.3180262], MSE = 47.78
# Iteration #100: W_new = [42.727794    4.23586294], MSE = 46.63
# Iteration #110: W_new = [43.07521157  4.17286412], MSE = 45.89
# Iteration #120: W_new = [43.34578807  4.12379924], MSE = 45.4
# Iteration #130: W_new = [43.55952748  4.08504089], MSE = 45.06
# ...

# %%
n = X.shape[1]

eta = 1e-2 
n_iter = 1001

W = np.array([1, 0.1])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    for k in range(W.shape[0]):
        W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    if i % 10 == 0:
        eta /= 1.1
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
# Out:
# Number of objects = 2
# Learning rate = 0.01
# Initial weights = [1.  0.1]
#
# Iteration #0: W_new = [ 6.52 19.63], MSE = 3201.27
# Iteration #10: W_new = [18.81737388  8.62067098], MSE = 397.4
# Iteration #20: W_new = [27.18278276  7.05472771], MSE = 206.56
# Iteration #30: W_new = [32.44525943  6.10044204], MSE = 124.36
# Iteration #40: W_new = [35.86750441  5.47987068], MSE = 86.39
# Iteration #50: W_new = [38.16308983  5.06360166], MSE = 67.71
# Iteration #60: W_new = [39.74678634  4.77642271], MSE = 57.99
# Iteration #70: W_new = [40.86752297  4.57319441], MSE = 52.66
# Iteration #80: W_new = [41.67914768  4.42601878], MSE = 49.6
# Iteration #90: W_new = [42.2793435   4.31718252], MSE = 47.76
# Iteration #100: W_new = [42.73169041  4.23515638], MSE = 46.62
# Iteration #110: W_new = [43.07852817  4.1722627 ], MSE = 45.88
# Iteration #120: W_new = [43.34865311  4.12327971], MSE = 45.39
# Iteration #130: W_new = [43.5620358   4.08458605], MSE = 45.06
# ...

# %% [markdown]
# Ответ: только изменение количества объектов и количества итераций позволили увидеть значимые изменения, параметры коэффициент скорости обучения и весовые коэффициенты не возволили увидеть значимые изменения.

# %% [markdown]
# 2*. В этом коде мы избавляемся от итераций по весам, но тут есть ошибка, исправьте ее

# %%
n = X.shape[0]

eta = 1e-2 
n_iter = 100

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
#     for k in range(W.shape[0]):
#         W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    # ИЗМЕНЕНИЯ
    W -= eta * (1/n * 2 * np.dot(y_pred - y, X))
    #
    if i % 10 == 0:
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err,2)}')
# Out:
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [2.08 4.27], MSE = 3047.75
# Iteration #10: W_new = [ 7.0011236 10.6169007], MSE = 738.65
# Iteration #20: W_new = [10.3486292  10.10603105], MSE = 622.03
# Iteration #30: W_new = [13.38789582  9.55618391], MSE = 525.24
# Iteration #40: W_new = [16.16088505  9.05336203], MSE = 444.66
# Iteration #50: W_new = [18.69110735  8.59454545], MSE = 377.58
# Iteration #60: W_new = [20.99981865  8.17589626], MSE = 321.72
# Iteration #70: W_new = [23.10641138  7.79389815], MSE = 275.22
# Iteration #80: W_new = [25.02858024  7.44534246], MSE = 236.5
# Iteration #90: W_new = [26.78247081  7.12730145], MSE = 204.27

# %% [markdown]
# Ответ: считаю, что ошибка в `W -= eta * (1/n * 2 * np.dot(X, y_pred - y))`, в части аргументов к функции `np.dot(y_pred - y, X)`

# %% [markdown]
# 3*. Вместо того, чтобы задавать количество итераций, задайте другое условие останова алгоритма - когда веса перестают изменяться меньше определенного порога  𝜖 .

# %% [markdown]
# С третьим заданием мне справиться не под силу.
