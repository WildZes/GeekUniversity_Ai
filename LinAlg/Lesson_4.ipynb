# %% [markdown]
# # Урок 6. Системы линейных уравнений. Часть 1

# %% [markdown]
# __1.__ Решить систему уравнений методом Гаусса:
#
# $$\begin{cases}
# x_{1}+x_{2}-x_{3}-2x_{4}=0, \\
# 2x_{1}+x_{2}-x_{3}+x_{4}=-2, \\
# x_{1}+x_{2}-3x_{3}+x_{4}=4.
# \end{cases}$$

# %% [markdown]
# Преобразуем расширенную матрицу системы путем элементарных преобразований:
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2\\
# 2 & 1 & -1 & 1\\
# 1 & 1 & -3 & 1
# \end{matrix}\right|
# \begin{matrix}
# 0\\
# -2\\
# 4
# \end{matrix}
# \end{pmatrix}$$
#
# Вычтем из второй строки первую, умноженную на 2 и из третьей строки первую:
# $$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 1 & -1 & -2\\
# 0 & -1 & 1 & 5\\
# 0 & 0 & -2 & 3
# \end{matrix}\right|
# \begin{matrix}
# 0\\
# -2\\
# 4
# \end{matrix}
# \end{pmatrix}$$
#
# Оставшаяся матрица соответствует системе:
# $$\begin{cases}
# x_{1}+x_{2}-x_{3}-2x_{4}=0, \\
# x_{3}-x_{2}+5x_{4}=-2, \\
# 3x_{4}-2x_{3}=4.
# \end{cases}$$
# Бесконечное множество решений принято записывать в виде общего решения.
# Последнее уравнение содержит две неизвестных. В данном случае можно рассматривать в качестве свободного параметра $x_{4}=c$. Тогда, выражая остальные переменные через $c$, получим:
# $$x_{4}=c,$$
# $$3c-2x_{3}=4 \; \Leftrightarrow \; x_{3}=\frac{3c-4}{2},$$
# $$\frac{3c-4}{2}-x_{2}+5c=-2 \; \Leftrightarrow \; x_{2}=2+\frac{3c-4}{2}+\frac{10c}{2}=6.5c,$$
# $$x_{1}+6.5c-\frac{3c-4}{2}-2c=0 \; \Leftrightarrow \; x_{1}=2c+\frac{3c-4}{2}+6.5c=10c-2.$$
# Таковым будет общее решение системы. Подставляя произвольные числа вместо $c$, мы получим частное решение. Например, при $c=0$:
# $$x_{1}=-2,$$
# $$x_{2}=0,$$
# $$x_{3}=-2,$$
# $$x_{3}=0.$$
#
# Параметр $c$ может принимать бесконечное количество значений, при которых уравнения в системе будут обращаться в тождества.

# %% [markdown]
# Выводы:
# - могу повторить то, что вижу в изучаемых материалах (принцип: "monkey see, monkey do"), но далеко не всегда понимаю применимость повторяемого;
# - не понял как и когда пришли к фразе "Бесконечное множество решений принято записывать в виде _общего решения_";
# - не понял как и когда пришли к фразе "Параметр $c$ может принимать бесконечное количество значений";
# - буду рад еще раз узнать более глубокий смысл изучаемого (более подробное объяснение указанных моментов), либо получить ссылку на материал, где наглядно и доступно объясняют применение изучаемого материала.

# %% [markdown]
# __2.__ Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений:
#
#    а) $\begin{cases}
# 3x_{1}-x_{2}+x_{3}=4, \\
# 2x_{1}-5x_{2}-3x_{3}=-17, \\
# x_{1}+x_{2}-x_{3}=0;
# \end{cases}$
#
#    б) $\begin{cases}
# 2x_{1}-4x_{2}+6x_{3}=1, \\
# x_{1}-2x_{2}+3x_{3}=-2, \\
# 3x_{1}-6x_{2}+9x_{3}=5;
# \end{cases}$
#
#    в) $\begin{cases}
# x_{1}+2x_{2}+5x_{3}=4, \\
# 3x_{1}+x_{2}-8x_{3}=-2.
# \end{cases}$

# %% [markdown]
# а)
# $\begin{pmatrix}
# \left.\begin{matrix}
# 3 & -1 & 1\\
# 2 & -5 & -3\\
# 1 & 1 & -1
# \end{matrix}\right|
# \begin{matrix}
# 4\\
# -17\\
# 0
# \end{matrix}
# \end{pmatrix}$

# %% [markdown]
# ### Неверный ход мысли.
# Прибавим к третьей строке первую, после чего поделим третью на 4:
# $\begin{pmatrix}
# \left.\begin{matrix}
# 3 & -1 & 1\\
# 2 & -5 & -3\\
# 1 & 0 & 0
# \end{matrix}\right|
# \begin{matrix}
# 4\\
# -17\\
# 1
# \end{matrix}
# \end{pmatrix}$
# Вычтем из второй строки третью, умноженную на 2:
# $\begin{pmatrix}
# \left.\begin{matrix}
# 3 & -1 & 1\\
# 0 & -5 & -3\\
# 1 & 0 & 0
# \end{matrix}\right|
# \begin{matrix}
# 4\\
# -19\\
# 1
# \end{matrix}
# \end{pmatrix}$
# Вычтем из третьей строки первую, поделенну на 3, после чего умножим третью строку на 3:
# $\begin{pmatrix}
# \left.\begin{matrix}
# 3 & -1 & 1\\
# 0 & -5 & -3\\
# 0 & 1 & -1
# \end{matrix}\right|
# \begin{matrix}
# 4\\
# -19\\
# -1
# \end{matrix}
# \end{pmatrix}$
# Прибавим к третьей строке вторую, поделенную на 5, после чего умножим третью строку на $\frac{5}{4}$:
# $\begin{pmatrix}
# \left.\begin{matrix}
# 3 & -1 & 1\\
# 0 & -5 & -3\\
# 0 & 0 & -2
# \end{matrix}\right|
# \begin{matrix}
# 4\\
# -19\\
# -5
# \end{matrix}
# \end{pmatrix}$

# %% [markdown]
# ### Окончательное решение
# Поделим первую строку на 3:
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & -\frac{1}{3} & \frac{1}{3}\\
# 2 & -5 & -3\\
# 1 & 1 & -1
# \end{matrix}\right|
# \begin{matrix}
# \frac{4}{3}\\
# -17\\
# 0
# \end{matrix}
# \end{pmatrix}$
# Отнимем из третьей строки первую, после чего умножим третью строку на $\frac{4}{3}$:
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & -\frac{1}{3} & \frac{1}{3}\\
# 2 & -5 & -3\\
# 0 & 1 & -1
# \end{matrix}\right|
# \begin{matrix}
# \frac{4}{3}\\
# -17\\
# -1
# \end{matrix}
# \end{pmatrix}$
# Отнимем из второй строки первую, умноженную на 2, после чего домножим вторую строку на 3:
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & -\frac{1}{3} & \frac{1}{3}\\
# 0 & -13 & -11\\
# 0 & 1 & -1
# \end{matrix}\right|
# \begin{matrix}
# \frac{4}{3}\\
# -59\\
# -1
# \end{matrix}
# \end{pmatrix}$
# Разделим вторую строку на -13, а затем отнимем из третьей строки втору, после чего умножим третью строку на $-\frac{13}{24}$:
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & -\frac{1}{3} & \frac{1}{3}\\
# 0 & 1 & \frac{11}{13}\\
# 0 & 0 & 1
# \end{matrix}\right|
# \begin{matrix}
# \frac{4}{3}\\
# \frac{59}{13}\\
# 3
# \end{matrix}
# \end{pmatrix}$
#
# Ответ: предполагаю, что система совместна и, так как ранг матрици равен количеству переменны, то будет одно решение.

# %% [markdown]
# б)
# $\begin{pmatrix}
# \left.\begin{matrix}
# 2 & -4 & 6\\
# 1 & -2 & 3\\
# 3 & -6 & 9
# \end{matrix}\right|
# \begin{matrix}
# 1\\
# -2\\
# 5
# \end{matrix}
# \end{pmatrix}$

# %% [markdown]
# Для удобства поменяю строки местами:
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & -2 & 3\\
# 3 & -6 & 9\\
# 2 & -4 & 6
# \end{matrix}\right|
# \begin{matrix}
# -2\\
# 5\\
# 1
# \end{matrix}
# \end{pmatrix}$
# Отнимем из третьей строки первую, умноженную на 2:
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & -2 & 3\\
# 3 & -6 & 9\\
# 0 & 0 & 0
# \end{matrix}\right|
# \begin{matrix}
# -2\\
# 5\\
# 5
# \end{matrix}
# \end{pmatrix}$
#
# Ответ: третья строка не имеет смысла, поэтому система несовместна

# %% [markdown]
# в)
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 5\\
# 3 & 1 & -8
# \end{matrix}\right|
# \begin{matrix}
# 4\\
# -2
# \end{matrix}
# \end{pmatrix}$
#
# Ответ: не представляю как можно выразить одну строку, через вторую, поэтому ранг счтаю равным 2, а так как ранг меньше количества переменных, то количество решений системы будет бесконечно.

# %% [markdown]
# Вывод:
# - с трудом понимаю, что я делаю (предположительно определяю имеет ли смысл пытаться решить систему, но как это применять в DS, пока не осознаю);
# - из методички не понял теорему Кронекера — Капелли, возможно часть методички у меня не отображается (основное непонимание заключается в определении расширенной матрицы, которое я пытался вычислить в интернете, но без особого успеха: [1](http://dict.scask.ru/index.php?id=1447));
# - ошибся, есть хороший [ресурс](https://www.webmath.ru/poleznoe/formules_5_1.php), который достаточно ступенчато все разъясняет, возможно этот ресрус будет полезен другим студентам.

# %% [markdown]
# __3.__ Проверить на совместность и выяснить, сколько решений будет иметь система линейных уравнений, заданная расширенной матрицей
#
# $$\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 3 & -2 & 4\\
# 0 & 5 & 0 & 1\\
# 0 & 0 & 3 & 0\\
# 0 & 0 & 0 & 2
# \end{matrix}\right|
# \begin{matrix}
# 3\\
# 2\\
# 4\\
# 1
# \end{matrix}
# \end{pmatrix}.$$

# %% [markdown]
# Согласно онлайн [калькулятору](https://ru.onlinemschool.com/math/assistance/matrix/rank/):
# Rank$\begin{pmatrix}
# 1 & 3 & -2 & 4\\
# 0 & 5 & 0 & 1\\
# 0 & 0 & 3 & 0\\
# 0 & 0 & 0 & 2
# \end{pmatrix} = 4$
#
# Согласно тому же калькулятору:
# Rank$\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 3 & -2 & 4\\
# 0 & 5 & 0 & 1\\
# 0 & 0 & 3 & 0\\
# 0 & 0 & 0 & 2
# \end{matrix}\right|
# \begin{matrix}
# 3\\
# 2\\
# 4\\
# 1
# \end{matrix}
# \end{pmatrix} = 4$
#
# Ответ: система совместна и определена.

# %% [markdown]
# __4.__ Дана система линейных уравнений, заданная расширенной матрицей
#
# $$\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 7 & 8 & 9
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b\\
# c
# \end{matrix}
# \end{pmatrix}.$$
#
# Найти соотношение между параметрами $a$, $b$ и $c$, при которых система является несовместной.

# %% [markdown]
# Отнимем из второй строки первую, умноженную на 4:
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 0 & -3 & -6\\
# 7 & 8 & 9
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b-4a\\
# c
# \end{matrix}
# \end{pmatrix}$
# Отнимем из третьей строки первую, умноженную на 7:
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 0 & -3 & -6\\
# 0 & -6 & -12
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b-4a\\
# c-7a
# \end{matrix}
# \end{pmatrix}$
# Отнимем из третьей строки вторую, умноженную на 2:
# $\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 0 & -3 & -6\\
# 0 & 0 & 0
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b-4a\\
# c+a-2b
# \end{matrix}
# \end{pmatrix}$
#
# Ответ: при $a-2b+c\ne0$ система несовместна.
#
# $\begin{cases}
# a \ne 2b-c \\
# b \ne \frac{a+c}{2} \\
# c \ne 2b-a
# \end{cases}$

# %% [markdown]
# # Урок 7. Системы линейных уравнений. Часть 2

# %% [markdown]
# __1.__ Решить систему уравнений методом Крамера:
#
#    а) $\begin{cases}
# x_{1}-2x_{2}=1 \\
# 3x_{1}-4x_{2}=7
# \end{cases}$
#
#    б) $\begin{cases}
# 2x_{1}-x_{2}+5x_{3}=10 \\
# x_{1}+x_{2}-3x_{3}=-2 \\
# 2x_{1}+4x_{2}+x_{3}=1
# \end{cases}$

# %% [markdown]
#    а) $\begin{cases}
# x_{1}-2x_{2}=1 \\
# 3x_{1}-4x_{2}=7
# \end{cases}$
# Найдем определитель матрицы:
# $detA=\begin{vmatrix}
# 1 & -2\\
# 3 & -4
# \end{vmatrix}=(1 \cdot -4) - (-2 \cdot 3) = 2$
# Найдем определитель $detA_{1}$:
# $detA_{1}=\begin{vmatrix}
# 1 & -2\\
# 7 & -4\\
# \end{vmatrix}=(1 \cdot -4) - (-2 \cdot 7) = 10$
# Найдем определитель $detA_{2}$:
# $detA_{2}=\begin{vmatrix}
# 1 & 1\\
# 3 & 7\\
# \end{vmatrix}=(1 \cdot 7) - (1 \cdot 3) = 4$
#
# Найдем значения $x_{1}, x_{2}$:
# $x_{1}=10/2=5$
# $x_{2}=4/2=2$
#
# Ответ: 5, 2

# %% [markdown]
#    б) $\begin{cases}
# 2x_{1}-x_{2}+5x_{3}=10 \\
# x_{1}+x_{2}-3x_{3}=-2 \\
# 2x_{1}+4x_{2}+x_{3}=1
# \end{cases}$
# Найдем определитель матрицы:
# $detA=\begin{vmatrix}
# 2 & -1 & 5\\
# 1 & 1 & -3\\
# 2 & 4 & 1
# \end{vmatrix}=2 + (2*(-1)*(-3)) + (5*4) - 10 + 1 - (2*4*(-3)) = 43$
# Найдем определитель detA_{1}:
# $detA_{1}=\begin{vmatrix}
# 10 & -1 & 5\\
# -2 & 1 & -3\\
# 1 & 4 & 1
# \end{vmatrix}=10 + (1*(-1)*(-3)) + (5*4*(-2)) - 5 - 2 - (10*4*(-3)) = 86$
# Найдем определитель detA_{2}:
# $detA_{2}=\begin{vmatrix}
# 2 & 10 & 5\\
# 1 & -2 & -3\\
# 2 & 1 & 1
# \end{vmatrix}=(2*(-2)) + 5 + (2*10*-3) - (5*2*(-2)) - (2*1*(-3)) - 10 = -43$
# Найдем определитель detA_{3}:
# $detA_{3}=\begin{vmatrix}
# 2 & -1 & 10\\
# 1 & 1 & -2\\
# 2 & 4 & 1
# \end{vmatrix}=2 + (2*(-1)*(-2)) + (10*1*4) - (10*2*1) - (2*4*(-2)) - (1*(-1)*1)= 43$
# $x_{1}=86/43=2$
# $x_{2}=-43/43=-1$
# $x_{3}=43/43=1$
#
# Ответ: 2, -1, 1

# %% [markdown]
# __2*.__ Найти $L$-матрицу $LU$-разложения для матрицы коэффициентов:
#
#    а)$$\begin{pmatrix}
# 1 & 2 & 4 \\
# 2 & 9 & 12 \\
# 3 & 26 & 30
# \end{pmatrix}$$
#
#    б)$$\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 2 & 5 & 8 & 9\\
# 3 & 18 & 29 & 18\\
# 4 & 22 & 53 & 33
# \end{pmatrix}$$

# %% [markdown]
#    а)$\begin{pmatrix}
# 1 & 2 & 4 \\
# 2 & 9 & 12 \\
# 3 & 26 & 30
# \end{pmatrix}$
# Начнем прямой ход метода Гаусса.
# $\begin{pmatrix}
# 1 & 2 & 4 \\
# 0 & 5 & 4 \\
# 3 & 26 & 30
# \end{pmatrix}$
# При этом запомним для матрицы L, элемента l21 значение 2.
# $\begin{pmatrix}
# 1 & 2 & 4 \\
# 0 & 5 & 4 \\
# 0 & 20 & 18
# \end{pmatrix}$
# При этом запомним для матрицы L, элемента l31 значение 3.
# $\begin{pmatrix}
# 1 & 2 & 4 \\
# 0 & 5 & 4 \\
# 0 & 0 & 2
# \end{pmatrix}$
# При этом запомним для матрицы L, элемента l32 значение 4.
#
# В итоге получим
#
# $U=\begin{pmatrix}
# 1 & 2 & 4 \\
# 0 & 5 & 4 \\
# 0 & 0 & 2
# \end{pmatrix},$
#
# $L=\begin{pmatrix}
# 1 & 0 & 0 \\
# 2 & 1 & 0 \\
# 3 & 4 & 1
# \end{pmatrix}.$

# %% [markdown]
#    б)$\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 2 & 5 & 8 & 9\\
# 3 & 18 & 29 & 18\\
# 4 & 22 & 53 & 33
# \end{pmatrix}$

# %% [markdown]
# Начнем прямой ход метода Гаусса.
# $\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 0 & 3 & 4 & 1\\
# 3 & 18 & 29 & 18\\
# 4 & 22 & 53 & 33
# \end{pmatrix}$
# При этом запомним для матрицы L, элемента l21 значение 2.
# $\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 0 & 3 & 4 & 1\\
# 0 & 15 & 23 & 6\\
# 4 & 22 & 53 & 33
# \end{pmatrix}$
# При этом запомним для матрицы L, элемента l31 значение 3.
# $\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 0 & 3 & 4 & 1\\
# 0 & 15 & 23 & 6\\
# 0 & 18 & 45 & 17
# \end{pmatrix}$
# При этом запомним для матрицы L, элемента l41 значение 4.
# $\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 0 & 3 & 4 & 1\\
# 0 & 0 & 3 & 1\\
# 0 & 18 & 45 & 17
# \end{pmatrix}$
# При этом запомним для матрицы L, элемента l32 значение 5.
# $\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 0 & 3 & 4 & 1\\
# 0 & 0 & 3 & 1\\
# 0 & 0 & 21 & 11
# \end{pmatrix}$
# При этом запомним для матрицы L, элемента l42 значение 6.
# $\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 0 & 3 & 4 & 1\\
# 0 & 0 & 3 & 1\\
# 0 & 0 & 0 & 4
# \end{pmatrix}$
# При этом запомним для матрицы L, элемента l43 значение 7.
#
# В итоге получим
#
# $U=\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 0 & 3 & 4 & 1\\
# 0 & 0 & 3 & 1\\
# 0 & 0 & 0 & 4
# \end{pmatrix}$
#
# $L=\begin{pmatrix}
# 1 & 0 & 0 & 0\\
# 2 & 1 & 0 & 0\\
# 3 & 4 & 1 & 0\\
# 5 & 6 & 7 & 1
# \end{pmatrix}.$

# %% [markdown]
# __3*.__ Решить систему линейных уравнений методом $LU$-разложения
#
# $$\begin{cases}
# 2x_{1}+x_{2}+3x_{3}=1 \\
# 11x_{1}+7x_{2}+5x_{3}=-6 \\
# 9x_{1}+8x_{2}+4x_{3}=-5
# \end{cases}$$

# %% [markdown]
# Матрица коэффициентов будет иметь вид
# $\begin{pmatrix}
# 2 & 1 & 3 \\
# 11 & 7 & 5 \\
# 9 & 8 & 4
# \end{pmatrix}$

# %% [markdown]
# Начнем прямой ход метода Гаусса. Для этого домножим первую строку на $5.5$ и вычтем ее из второго уравнения. При этом запишем в матрицу $L$ на место элемента $l_{21}$ значение $5.5$. Затем нам нужно вычесть из третьего уравнения первое, домноженное на $4.5$. Значит, в матрицу $L$ запишем $l_{31}=4.5$. Далее умножим вторую строку на $\frac{7}{3}$ и вычтем ее из третьей. При этом в матрицу $L$ на место $l_{32}$ запишем $\frac{7}{3}$.
#
# В итоге получим
#
# $U=\begin{pmatrix}
# 2 & 1 & 3 \\
# 0 & \frac{3}{2} & -\frac{161}{6} \\
# 0 & 0 & \frac{52}{3}
# \end{pmatrix},$
#
# $L=\begin{pmatrix}
# 1 & 0 & 0 \\
# \frac{11}{2} & 1 & 0 \\
# \frac{9}{2} & \frac{7}{3} & 1
# \end{pmatrix}.$
#
# Решим теперь систему
#
# $Ly=b:$
#
# $\begin{cases}
# y_{1}=1, \\
# \frac{11}{2}y_{1}+y_{2}=-6, \\
# \frac{9}{2}y_{1}+\frac{7}{3}y_{2}+y_{3}=-5.
# \end{cases}$
#
# $y_{1}=1,$
# $y_{2}=-\frac{23}{2},$
# $y_{3}=\frac{52}{3}.$
#
# И затем систему
#
# $Ux=y:$
#
# $\begin{cases}
# 2x_{1}+x_{2}+3x_{3}=1, \\
# \frac{3}{2}x_{2}-\frac{161}{6}x_{3}=-\frac{23}{2}, \\
# \frac{52}{3}x_{3}=\frac{52}{3}.
# \end{cases}$
#
# $x_{3}=1,$
# $x_{2}=\frac{92}{9},$
# $x_{1}=-\frac{55}{9}.$
#
# Произведем проверку, подставив полученные значения переменных в исходную систему:
#
# $$\begin{cases}
# -2\cdot\frac{55}{9}+\frac{92}{9}+3=1, \\
# -11\cdot\frac{55}{9}+7\cdot\frac{92}{9}+5=-6, \\
# -9\cdot\frac{55}{9}+8\cdot\frac{92}{9}+4=-5.
# \end{cases}$$
#
# Из второго уравнение видим:
# $\frac{39}{9}+5 \ne -6$
# Решение найдено неверно.

# %%
import scipy
import scipy.linalg

A = scipy.array([[2,1,3], [11,7,5], [9,8,4]])
_, L, U = scipy.linalg.lu(A)
(L,U)
# Out:
# /home/mrp/anaconda3/envs/FR/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: scipy.array is deprecated and will be removed in SciPy 2.0.0, use numpy.array instead
#   after removing the cwd from sys.path.
# (array([[ 1.        ,  0.        ,  0.        ],
#         [ 0.81818182,  1.        ,  0.        ],
#         [ 0.18181818, -0.12      ,  1.        ]]),
#  array([[11.        ,  7.        ,  5.        ],
#         [ 0.        ,  2.27272727, -0.09090909],
#         [ 0.        ,  0.        ,  2.08      ]]))

# %%
import numpy as np
A = np.array([[2,1,3], [11,7,5], [9,8,4]])
B = np.array([1, -6, -5])
np.linalg.solve(A, B )
# Out:
# array([-1.,  0.,  1.])

# %% [markdown]
# Вывод: прекрасно, что есть готовые бибилиотеки для решения подобных задач, так как я могу не скоро научиться вручную решать подобные системы.
